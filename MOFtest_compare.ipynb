# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pickle as p
import astropy.io.fits as fits 
import healpy as hp
import pandas
from astropy.table import Table,join

# %%
#my example output
myfile="/global/homes/a/aamon/DES/deepfields/test.fits"
dat = fits.open(myfile)
dat.info() 
dat[1].header
print(dat[1].header)
mydata= dat[1].data

iwant = dat[1].header['TTYPE*']

print("xxxxxxxxxxxxxxxxxxxxxxxx")
print(iwant)
print("xxxxxxxxxxxxxxxxxxxxxxxx")
dat[1].data['id']

my_tab = Table(dat[1].data)
print(my_tab)
# Out:
# Filename: /global/homes/a/aamon/DES/deepfields/test.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  model_fits    1 BinTableHDU     74   13R x 31C   [K, D, D, K, J, 11A, E, 2D, D, 9J, 9D, 9D, 9D, 9D, J, J, D, 15D, 15D, 225D, 2D, 4D, D, D, D, 9D, 9D, 81D, 9D, D, D]
#   2  epochs_data    1 BinTableHDU     17   228R x 4C   [K, I, J, 18D]
# ...

# %%
#my example output
erinfile="/global/homes/a/aamon/DES/deepfields/run-vd01.fits"
dat2 = fits.open(erinfile)
dat2.info() 
dat2[1].header
print(dat2[1].header)
erindata= dat2[1].data
print("xxxxxxxxxxxxxxxxxxxxxxxx")


iwant = dat[1].header['TTYPE*']
print(iwant)
print("xxxxxxxxxxxxxxxxxxxxxxxx")
dat2[1].data['id']

erin_tab = Table(dat2[1].data)
print(erin_tab)
dat2[1].data['bdf_flux']
# Out:
# Filename: /global/homes/a/aamon/DES/deepfields/run-vd01.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  model_fits    1 BinTableHDU     74   13181R x 31C   [K, D, D, K, J, 11A, E, 2D, D, 9J, 9D, 9D, 9D, 9D, J, J, D, 15D, 15D, 225D, 2D, 4D, D, D, D, 9D, 9D, 81D, 9D, D, D]
#   2  epochs_data    1 BinTableHDU     17   207978R x 4C   [K, I, J, 18D]
# ...

# %%
join(erin_tab, my_tab, keys=['id'])
# Out:
# <Table length=13>
#     id         ra_1         dec_1      ...  bdf_fracdev_2  bdf_fracdev_err_2
#   int64      float64       float64     ...     float64          float64
# --------- ------------- -------------- ... --------------- -----------------
# 692217003  52.754150333 -28.0754908457 ...  0.234843057174    0.003372532963
# 692217144 52.7960655186 -28.0756388228 ...  0.667954525501   0.0132221058357
# 692217149 52.5848213282 -28.0756680024 ...   0.49768796569   0.0387561865335
# 692217176 52.6152100114 -28.0759482544 ...  0.499868655099   0.0359279279654
# 692217178 52.7431068764 -28.0759446254 ...  0.499992388071   0.0355752171548
# 692217179  52.794880456 -28.0759132989 ...  0.054998939192  0.00718011625581
# 692217182 52.7960152287 -28.0762453936 ...  0.634475280841    0.013180713338
# 692217183 52.5478583141 -28.0760290175 ... -0.360165778579   0.0289707099702
# 692217184 52.6273680992 -28.0765328237 ...  0.498055719035   0.0391065189566
# ...

# %%
print(my_tab)
# Out:
#     id          ra           dec       ...   bdf_fracdev   bdf_fracdev_err
# --------- ------------- -------------- ... --------------- ----------------
# 692217191 52.6297775939 -28.0761440438 ...  0.536794601968  0.0335694077983
# 692217190 52.5957448208 -28.0760984395 ...  0.488293792224  0.0371614685834
# 692217188 52.5850728166 -28.0761189104 ...  0.105702287648 0.00850918241414
# 692217149 52.5848213282 -28.0756680024 ...   0.49768796569  0.0387561865335
# 692217187 52.7531160166 -28.0761072007 ...  0.039925678408 0.00297616840375
# 692217003  52.754150333 -28.0754908457 ...  0.234843057174   0.003372532963
# 692217184 52.6273680992 -28.0765328237 ...  0.498055719035  0.0391065189566
# 692217183 52.5478583141 -28.0760290175 ... -0.360165778579  0.0289707099702
# 692217182 52.7960152287 -28.0762453936 ...  0.634475280841   0.013180713338
# 692217144 52.7960655186 -28.0756388228 ...  0.667954525501  0.0132221058357
# ...

# %%
matches=join(erin_tab, my_tab, keys=['id'])
print(len(matches['bdf_flux_1'][0]))
matches['bdf_flux_1'][0], matches['bdf_flux_1'][1]
# Out:
# 9
# (array([   433.56572288,    234.21197989,    288.6339187 ,    272.04581556,
#           1736.72050552,  16707.85018825,    236.16033498,   1150.20222467,
#           -999.77717817]),
#  array([  78.21146736,  124.46974218,  152.38417702,  173.60032931,
#          165.32550216,  242.57116934,  165.58151068,  237.85448132,
#          126.26178781]))

# %%
for i in range(0,9):
    plt.scatter(matches['bdf_flux_1'][1],matches['bdf_flux_2'][1])
    plt.xlabel("ERIN BDF_FLUX")
    plt.ylabel("ALEX BDF_FLUX")
